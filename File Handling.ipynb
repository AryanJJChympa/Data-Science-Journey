# %%
file = open("aj.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# 2026 is going to be the year

# %%
with open("aj.txt", "w") as file:
    file.write("2026 is going to be the year \n")
    
print("File written successfully")
# Out:
# File written successfully

# %%
with open("aj.txt", "a") as f:
    f.write("\n I am Aryan, a BCA gradguate")

with open("aj.txt", "r") as fi:
    content = fi.read()
print(content)
# Out:
# 2026 is going to be the year
#
#  I am Aryan, a BCA gradguate
#  I am Aryan, a BCA gradguate
#  I am Aryan, a BCA gradguate
#  I am Aryan, a BCA gradguate
#  I am Aryan, a BCA gradguate
#  I am Aryan, a BCA gradguate
